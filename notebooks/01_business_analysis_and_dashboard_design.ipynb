# %% [markdown]
# # 📊 Proyecto: Dashboard de desempeño comercial 2024–2025
# Empresa: **Andes Retail Group**
#
# Este notebook servirá como guía estructurada para el desarrollo del proyecto.
# Sigue cada paso y espera feedback del evaluador.

# %% [markdown]
# ## 🔹 Paso 1: Conexión y Exploración
#
# - Importa el archivo excel en Power BI Desktop o en Tableau.
# - Revisa tipos de datos.
# - Identifica columnas clave.
# - Explora estructura general del dataset.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 2: Preparación de los datos
#
# - Cambia el formato de `Fecha_pedido` a español (Latinoamérica).
# - Corrige los **tipos de datos** de columnas numéricas.
# - Crea una columna condicional `Nivel_Venta` basada en `Ingresos`. Reglas:
#   - Si `Ingresos` es mayor o igual a 1000 → "Venta Alta"
#   - De lo contrario → "Venta Baja"
# - Activa **Vista Perfil de Columna** para validar calidad.
# - Deja el dataset listo para análisis.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 3: Diseño y planificación del Dashboard (antes y durante la construcción)
#
# - Define qué pregunta responde cada vista (Overview y Detalle).
#       * Respuesta: Overview debe responder ¿Cómo está el negocio en general?
#                    Detalle debe responder ¿Dónde están las diferencias, patrones u oportunidades?
# - Especifica qué KPIs incluirás y por qué.
#       * Respuesta: ingresos totales: a donde llegaron.
#                   Coeficiente de variación: si el negocio depende de una sola región.
#                   YoY de ingresos, costes y unidades: ver la dirección de estas tres variables.
#                   YoY de AOV, ARPU, ASP y UPT: ver la dirección de estas 4 variables.
# - Explica qué gráfico usarás para cada pregunta y justifica la elección.
#       * Respuesta: ¿Cómo ha evolucionado el ingreso total entre 2024 y 2025? y ¿Qué segmentos de clientes aportan mayor ingreso y rentabilidad? con un gráfico de dispersión por tipo de cliente que muestre ingresos y el YoY de ingresos, ingresos y margen de ganancia.
#                     ¿Qué categorías de producto tienen mayor impacto en el negocio? con un gráfico de barras horizontal mostrando ingresos, YoY de ingresos, con dos alertas visuales ratio de costo de eficiencia > 70% y el margen de ganancia < 35%.
#                     ¿Existen diferencias relevantes entre países o regiones? En Overview se analiza por país y en detalle por región de cada país.
#                     ¿Qué patrones temporales se observan a lo largo del año? con un gráfico de líneas ingresos en el tiempo, indicando el mínimo y el máximo, con la alerta de índice de estacionalidad calculado por estación. Adicional, un gráfico de barras horizontal por estación y por nivel_venta de ingresos con unidades vendidas.
#                       ¿Dónde podrían existir oportunidades de mejora comercial? Por país en overview y por región de país en detalle.
# - Describe la jerarquía visual (qué verá primero el usuario).
#     - Indica cómo distribuirás los elementos en la página.
#       * Respuesta: primera vista los KPI´s, gráfico de líneas (ingresos en el tiempo), gráfico de barras horizontal de ingresos, YoY ingresos por categoría, gráfico de barras horizontal de total unidades vendidas y sus ingresos por nivel_vental y estación, por último, gráfico de dispersión de YoY ingresos, ingresos y margen de ganancia.
# - Especifica qué filtros o segmentadores usaras.
#                     Respuesta: en overview año y país, detalles país y región.

# %% [markdown]
# ### Diseño y planificación
# ✏️ Describe aquí brevemente tu planificación antes de construir el dashboard.
# - Haz una planeación inicial, después, conforme vayas creando el dashboard, puedes regresar y modificar estas secciones acorde a lo que vayas encontrando.
#
# #### Vista Overview - ¿Cómo ha evolucionado el ingreso total entre 2024 y 2025?
# Especifica qué KPIs incluirás y por qué: (3-4 KPIs)
#
# - Ingresos totales: ver a dónde llegaron.
# - Coeficiente de variación: revisar si el negocio depende de una sola región.
# - YoY de ingresos, costes y unidades: ver la dirección de estas tres variables.
# - YoY de AOV, ARPU, ASP y UPT: ver la dirección de estas 4 variables.
#
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
#
# ¿Cómo ha evolucionado el ingreso total entre 2024 y 2025? y ¿Qué segmentos de clientes aportan mayor ingreso y rentabilidad? con un gráfico de dispersión por tipo de cliente que muestre ingresos y el YoY de ingresos, ingresos y margen de ganancia.
#                     ¿Qué categorías de producto tienen mayor impacto en el negocio? con un gráfico de barras horizontal mostrando ingresos, YoY de ingresos, con dos alertas visuales ratio de costo de eficiencia > 70% y el margen de ganancia < 35%.
#                     ¿Existen diferencias relevantes entre países o regiones? En Overview se analiza por país y en detalle por región de cada país.
#                     ¿Qué patrones temporales se observan a lo largo del año? con un gráfico de líneas ingresos en el tiempo, indicando el mínimo y el máximo, con la alerta de índice de estacionalidad calculado por estación. Adicional, un gráfico de barras horizontal por estación y por nivel_venta de ingresos con unidades vendidas.
#                       ¿Dónde podrían existir oportunidades de mejora comercial? Por país en overview y por región de país en detalle.
#
# - Gráfico de tiempo: ingresos por mes segmentado por estación y como alerta el índice de estacionalidad. Para detectar los valles comerciales.
# - Gráfico comparación geográfica: se utiliza el overview por país comparando el comportamiento por país.
# - Gráfico comparación clientes/productos: para clientes gráfico de dispersión con el YoY de ingresos, ingresos y margen de ganancias. Para detectar el segmento de mayor ganancias y margen.
#                                         Para productos gráfico de barras horizontal de ingresos con YoY de ingresos, y alerta de eficiencia de costo > 70% y margen de ganacia < 35%, para detectar que elemento tiene mayor ingresos y que relación tiene con su costo de operación y que margen de ganacias tiene.
#
# Descripción de la jerarquía visual:
# - KPI: CY Revenue
# - KPI: CV country
# - KPI: YoY Revenue, YoY costs, YoY units
# - KPI: YoY AOV, YoY ARPU, YoY, YoY ASP, YoY UPT
# - Revenue performance by month
# - It is shows the Revenue and YoY by category
# - Count of sold units and its sum revenue
# - Revenue Growth YoY performance by revenue customer segment
#
# Filtro(s)
# - Año
# - País
# - Región
#
# #### Vista detalle - ¿Por qué se han caido/subido/mantenido los ingresos?
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Gráfico comparación estacional contra ingresos: Gráfico de líneas - `Ingresos` vs `Fecha pedido`. Ver la evolución de las ventas a traves por mes y por estación.
# - Gráfico comparación categoría producto contra ingresos : Gráfico de barras horizontal - `categoría producto` vs `ingresos`. Ver el desempeño de los ingresos por categoria del producto y ver si son costos de operación alto y su margen de ganancia, si son rentables.
# - Gráfico comparación estacional contra unidades vendidas y nivel_venta : Gráfico de barras horizontal - `estación` vs `unidades vendidas` por `nivel_venta`. Ver el desempeño de las unidades vendidas por estación y por nivel_venta detectando los valles comerciales.
# - Gráfico comparación ingresos contra YoY ingresos por segmento tipo cliente: Gráfico de dispersión - `ingresos` vs `YoY ingresos` por `segmento cliente`. Ver el desempeño del segmento cliente, cuanto ingresos generan, cuanto margen de ganacia se obtiene, el desempeño del YoY ingresos.
# - Tabla mostrando 4-6 columnas:
# - N/A
#
# Filtros (mínimo 2)
# - `Año`
# - `País`
# - `Región`

# %% [markdown]
# ## 🔹 Paso 4: Crear visualizaciones efectivas
#
# - Construir Vista 1 (Overview Ejecutivo).
# - Construir Vista 2 (Análisis Detallado).
# - Asegurar claridad y coherencia visual.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 5: Narrativa con Modelo SCQA + mensaje asincrónico
#
# - Escribe la narrativa que
#   - refleja lo que se observa en la **Vista General (Overview)**.
#   - explica los hallazgos en la **Vista Detalle**.
# - Utiliza el modelo **SCQA (Situación, Complicación, Pregunta, Respuesta)**.
# - Mantén la narrativa clara, ejecutiva y breve.
# - Redacta un mensaje ejecutivo tipo Slack resumiendo el insight principal.

# %% [markdown]
# ### Narrativa del Dashboard (Modelo SCQA)
# Se describe de forma estructurada la historia completa del dashboard usando SCQA, incluyendo contexto, problemas detectados, preguntas de negocio y recomendaciones basadas en datos.

# %% [markdown]
# #### 🖥️ Vista General (Overview)
#
# **S (Situación):**
# Se observa la dirección en la que va el negocio general y por país
#
# **C (Complicación):**
# Se observa que la dirección del negocio se ha contraído un 12.1% en ingresos y 11.4% de unidades vendidas, reflejando una disminución del 11.1% en costos operativos.
#
# **Q (Pregunta):**
# ¿Existieron valles comerciales bajos o algún país y sus regiones presentaron bajas demandas?
#
# **A (Respuesta):**
# El país con mayor contracción fue Perú con una contracción del 10% en ingresos y unidades vendidas.
#
# ---
#
# #### 🔎 Vista Detalle
#
# **S (Situación):**
# Se observa la dirección que tiene el negocio por país y por región
#
# **C (Complicación):**
# Se observa algunas contracciones por cada región.
#
# **Q (Pregunta):**
# ¿Existieron valles comerciales bajos o alguna región presentó bajas demandas?
#
# **A (Respuesta):**
# La región centro tiene una contracción del 19% en ingresos y unidades vendidas.

# %% [markdown]
# ### Mensaje asincrónico para Slack (Modelo SCQA)
#
# Resume los insights más importantes en un mensaje breve.
# - Comunica impacto en negocio y acciones recomendadas, como si lo enviaras a stakeholders por Slack.
# - Escribe un mensaje directo y conciso.

# %% [markdown]
# **📊 Actualización desempeño comercial**
#
# En el estudio del desempeño comercial del año 2024-2025, se observó una contración del 12.1% en ingresos y 11.4% en unidades vendidas.
#
# Revisando a detalle, Perú tuvo una contracción general del 10% de ingresos y unidades vendidas.
#
# En la región centro de Perú tuvo una contracción del 19% en ingresos y unidades vendidas.
#
# Se recomienda revisar si las campañas, promociones aplicadas fueron ineficientes.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios._

# %% [markdown]
# ## 🚀 Entrega Final
#
# Comparte el acceso a tu proyecto final para revisión.
#
# Incluye **una** de las siguientes opciones, según la herramienta que hayas utilizado:
# - 🔗 Link público del dashboard publicado (Power BI Service o Tableau Public), o
# - 🔗 Link público de Google Drive/OneDrive con el archivo `.pbix`, o
# - ✅ Confirmación de que el archivo `.pbix` fue subido como indica el screencast.
#
# ### 📎 Enlace del proyecto:

# %% [markdown]
# ✏️ (Pega aquí tu link o escribe "Subi mi proyecto a la plataforma")
#
#
# Opción 1: https://public.tableau.com/app/profile/jacobo.galindo.ortiz/viz/Andes_Retail_Group_2024_2025/Porpas?publish=yes
#
# Opción 2: https://drive.google.com/file/d/1iSNzCbuhooeLyiMwbethUjCZ-wDpKh27/view?usp=sharing
#
# Opción 3: También lo cargué aquí.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br><br>
#
# Hola, Jacobo. Realizaste un excelente trabajo.
#
# <b>Éxito.</b> El proyecto cumple con lo solicitado: el dashboard es funcional, coherente y comunica hallazgos accionables con datos bien preparados.<br><br>
#
# <b>1) Conexión de los datos</b><br>
# ✅ El objetivo esta muy bien logrado de la conexión de los datos de excel en Power BI, la cual carga sin errores. <br><br>
#
# <b>2) Preparación y calidad de datos (power query)</b><br>
# ✅ Se gestionan correctamente tipos de datos, los tipos de variables. Es importantegregar tarjetas para mostrar indicadores como la ganancia, margen promedio y total de pedidos.<br><br>
#
# <b>3) Planificación y diseño</b><br>
# ✅ Los KPIs están bien seleccionados, correctamente calculados y alineados con el objetivo (incluye definiciones claras, unidades y periodos de referencia). Además, el orden en el que los colocas es correcta para llevar una secuencia lógica<br><br>
#
# <b>4) Análisis e insights</b><br>
# ✅ El análisis identifica patrones relevantes (tendencias, segmentos, outliers) y los interpreta con lógica de negocio. Los insights están respaldados por evidencia en el dashboard.<br><br>
#
# <b>5) Visualización y diseño del dashboard</b><br>
# ✅ Diseño limpio y legible: jerarquía visual adecuada, títulos informativos, etiquetas claras. Solamente te recomiendo colocar filtros útiles. Las gráficas son apropiadas para cada métrica y no generan confusión. Muestras ls gráficos de tendencia temporal, comparación geografica, comparación de estación, detalles de ventas,  entre otros<br><br>
#
# <b>6) Interactividad y usabilidad</b><br>
# ✅ La navegación es intuitiva. El usuario puede llegar a conclusiones mediante las pestañas que agregas. Ya solamente para terminar de complementar tu tablero puedes agregar diferentes filtros con las variables que tienes, como  país. <br><br>
#
# <b>7) Reproducibilidad y buenas prácticas</b><br>
# ✅ Código ordenado, con pasos claros, nombres consistentes y comentarios donde aportan valor. Estructura replicable (carga → limpieza → análisis → visualización).<br><br>
#
# Solamente en futuros casos puedes seguir explorando herramientas como conectar los filtros entre pestañas y gráficos por estaciones.
#
#
# <b>Resultado:</b> Proyecto aprobado. Excelente trabajo.
